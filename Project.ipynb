# %%
import pandas as pd

# %% [markdown]
# Importing The Train Split Dataset

# %%
df= pd.read_csv("train.csv")

# %% [markdown]
# Checking the First 5 Rows Of the Train Dataset

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# Checking For Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %% [markdown]
# Creating The Clean Data

# %%
data_cleaned=df.drop(['Unnamed: 0','id'],axis=1)

# %% [markdown]
# Fixing the Missing Value with Linear Interpolation

# %%
data_cleaned['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].interpolate(method='linear')

# %%
data_cleaned.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %% [markdown]
# Getting Rid of the object-type columns with Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
encoded_need=[]
for i in data_cleaned.columns:
  if data_cleaned[i].dtype=='object':
    encoded_need.append(i)

# %%
for i in encoded_need:
  data_cleaned[i]=label_encoder.fit_transform(data_cleaned[i])

# %%
data_cleaned.dtypes
# Out:
# Gender                                 int64
# Customer Type                          int64
# Age                                    int64
# Type of Travel                         int64
# Class                                  int64
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %% [markdown]
# Checking for the correlation between Features

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features=data_cleaned.iloc[:,:-1]
features.head(2)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# 1                       3              3  ...             1
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# 1                       1                 1                 5
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(features.corr(), center=0, cmap='crest',annot=True)
ax.set_title('Multi-Collinearity of Health Attributes')
plt.show()

# %% [markdown]
# Creating the function to extract the high correlated features

# %%
def correlation(df,threshold):
  correlated_cols=set()
  corr_mat=df.corr()
  for i in range(len(corr_mat.columns)):
    for j in range(i):
      if abs(corr_mat.iloc[i,j])>threshold:
        col=corr_mat.columns[i]
        correlated_cols.add(col)
  return correlated_cols

# %% [markdown]
# EXtracting the high correlated Features

# %%
corr_feature=correlation(features,0.6)
corr_feature
# Out:
# {'Arrival Delay in Minutes',
#  'Cleanliness',
#  'Ease of Online booking',
#  'Inflight entertainment',
#  'Inflight service'}

# %% [markdown]
# Removing them from the DataSet

# %%
features.drop(labels=corr_feature,axis=1,inplace=True)
